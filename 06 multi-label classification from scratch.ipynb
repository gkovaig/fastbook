# %%
# !pip install -Uqq fastbook
from fastbook import *
from fastai.vision.all import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a6da05688f92> in <module>()
#       1 get_ipython().system('pip install -Uqq fastbook')
# ----> 2 import fastbook
#       3 from fastai.vision.all import *
#
# /usr/local/lib/python3.6/dist-packages/fastbook/__init__.py in <module>()
#       1 __version__ = "0.0.16"
#       2 import matplotlib as mpl, pkgutil, requests, time
# ----> 3 from fastai.vision.all import *
#       4 from pandas.api.types import CategoricalDtype
#       5 from scipy.cluster import hierarchy as hc
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/all.py in <module>()
#       1 from . import models
#       2 from ..basics import *
# ----> 3 from ..callback.all import *
#       4 from .augment import *
#       5 from .core import *
#
# ModuleNotFoundError: No module named 'fastai.callback.all'; 'fastai.callback' is not a package
#
# ...

# %%
setup_
